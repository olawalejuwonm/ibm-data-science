# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <!-- #Cell 1 (rendered as Markdown): The title should be "My Jupyter Notebook on IBM Watson Studio", in H1 header styling. The title does #not need to be centered -->
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <!-- Include your name, in bold characters. In the line below your name, write your current or desired occupation in regular font -->
#
# <b>Olawale Juwon</b> <br> Software Engineer <br>

# %% [markdown]
# <!-- In italic formatting, write one or two sentences about why you are interested in data science. For example, you can start your first sentence with "I am interested in data science because ...". -->
# <i>I am interested in data science because I am a software engineer and I am passionate about building products that help people.</i>
# <i> I am also interested in data science because I am a data scientist and I am passionate about building products that help people.</i>

# %% [markdown]
# <!-- In H3 header styling, explain in a short sentence what your code is supposed to do in Cell 5. -->
# <h3>The code below is supposed to print "Hello World" to the console.</h3>

# %%
print("Hello World")

# %% [markdown]
# <!-- Using Markdown or HTML, this cell must include at least 3 of the following: horizontal rule, bulleted list, numbered list, tables, hyperlinks, images, code/syntax highlighting, blocked quotes, strikethrough. -->
#
# Horizontal rule:
# <hr>
# Bulleted list:
# <ul>
#     <li>Item 1</li>
#     <li>Item 2</li>
#     <li>Item 3</li>
# </ul>
# Numbered list:
# <ol>
#     <li>Item 1</li>
#     <li>Item 2</li>
#     <li>Item 3</li>
# </ol>
# Tables:
# <table>
#     <tr>
#         <th>Header 1</th>
#         <th>Header 2</th>
#         <th>Header 3</th>
#     </tr>
#     <tr>
#         <td>Item 1</td>
#         <td>Item 2</td>
#         <td>Item 3</td>
#     </tr>
#     <tr>
#         <td>Item 1</td>
#         <td>Item 2</td>
#         <td>Item 3</td>
#     </tr>
# </table>
# Hyperlinks:
# <a href="https://www.google.com">Google</a>
# <a href="https://www.ibm.com">IBM</a>
# <a href="https://www.cognitiveclass.ai">CognitiveClass</a>
# <a href="https://www.facebook.com">Facebook</a>
# <a href="https://www.twitter.com">Twitter</a>
# Code/syntax highlighting:
# <pre>
# <code>print("Hello World")</code>
# </pre>
# Images:
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Images/Learning_Resources_Images/Python_Logo.png" width="200" alt="Python Logo" />
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Images/Learning_Resources_Images/Watson_Logo.png" width="200" alt="Watson Logo" />
# Blocked quotes:
# <blockquote>
#     <p>
#         "I am a data scientist and I am passionate about building products that help people."
#     </p>
# </blockquote>
# <blockquote>
#     <p>
#         "I am a software engineer and I am passionate about building products that help people."
#     </p>
# </blockquote>
# Strikethrough:
# <s>
#     <p>
#         I am a data scientist and I am passionate about building products that help people.
#     </p>
# </s>

# %% [markdown]
# <!-- Include your name, in bold characters. In the line below your name, write your current or desired occupation in regular font -->
